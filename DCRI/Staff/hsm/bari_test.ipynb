# %%
import pandas as pd
baribl=pd.read_csv('../scratch/BARI2D/data/BARI2D_BL.csv')

# %%
baribl.head()
# Out:
#   strata mdins hxetoh palev regex slfhlth slfscore angeq6w hxmi hxchf  ...    \
# 0    PCI     2      0     1     0       4       20       1    0     0  ...
# 1    PCI     2      0     3     1       3       50       1    0     0  ...
# 2   CABG     1      0     2     0       2       70       1    1     0  ...
# 3    PCI     3      0     3     1       4       50       0    0     0  ...
# 4    PCI     3      0     2     0       3       65       1    0     0  ...
#
#   race nhhp workstat age rand_year  apa pulse60_sit abilow    bmi     id
# 0    2  3.0      3.0  47      2003  0.0        87.0    0.0  36.02  N1101
# 1    1  2.0      2.0  71      2003  0.0        61.0    0.0  24.49  N1102
# 2    1  2.0      2.0  73      2001  1.0        77.0    0.0  26.28  N1106
# 3    1  4.0      1.0  40      2003  0.0        68.0    0.0  32.38  N1107
# 4    1  3.0      1.0  52      2002  0.0        80.0    0.0  37.71  N1108
#
# [5 rows x 84 columns]

# %%
#baribl.shape
#baribl.columns
baribl.describe()
# Out:
#             screat      spotass          sex      cardtrt      diabtrt  \
# count  2355.000000  2343.000000  2368.000000  2368.000000  2368.000000
# mean      1.044059     4.322207     1.296453     0.496622     0.500422
# std       0.278317     0.470761     0.456789     0.500094     0.500105
# min       0.100000     2.400000     1.000000     0.000000     0.000000
# 25%       0.860000     4.000000     1.000000     0.000000     0.000000
# 50%       1.000000     4.300000     1.000000     0.000000     1.000000
# 75%       1.200000     4.600000     2.000000     1.000000     1.000000
# max       2.400000     6.400000     2.000000     1.000000     1.000000
#
#             educat       energy     hlthdist         dasi     angcls6w  \
# count  2344.000000  2334.000000  2333.000000  2335.000000  2365.000000
# mean      2.043942    51.353363    40.497750    18.945931     2.457505
# std       0.883402    22.909620    25.289581    13.492913     1.373390
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')
#baribl.hist(figsize=(15, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f723b696910>,
# ...
#       dtype=object)

# %%
bari_sub=baribl.loc[:, ['abi', 'bmi', 'age', 'sex', 'trig']]
bari_sub.hist(figsize=(10, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7239f7f890>,
# ...
#       dtype=object)
